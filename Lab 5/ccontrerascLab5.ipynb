# %% [markdown]
# # $1.Ethereum$

# %% [markdown]
# *Ethereum is a decentralized, open-source blockchain with smart contract functionality. Ether (ETH) is the native cryptocurrency of the platform. It is the second-largest cryptocurrency by market capitalization, after Bitcoin. Ethereum is the most actively used blockchain.*

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2121, 1, 1)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        self.eth = self.AddEquity("ETH", Resolution.Minute)
        self.eth.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        if not self.Portfolio.Invested:
            self.MarketOrder("ETH", 100)
            self.Debug( str(self.Portfolio["ETH"].AveragePrice))

# %% [markdown]
# ![Ethereum.png](data:image/png;base64,...)

# %% [markdown]
# **Valor de paquete de 100 acciones al inicio:** $100,000
#
# **Valor de paquete de 100 acciones al final:** $101,500

# %% [markdown]
# # $2. AMD$

# %% [markdown]
# *Advanced Micro Devices, Inc. (AMD) is an American multinational semiconductor company based in Santa Clara, California, that develops computer processors and related technologies for business and consumer markets. While it initially manufactured its own processors, the company later outsourced its manufacturing, a practice known as going fabless, after GlobalFoundries was spun off in 2009. AMD's main products include microprocessors, motherboard chipsets, embedded processors and graphics processors for servers, workstations, personal computers and embedded system applications.*

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2121, 1, 1)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        self.amd = self.AddEquity("AMD", Resolution.Minute)
        self.amd.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        if not self.Portfolio.Invested:
            self.MarketOrder("AMD", 100)
            self.Debug( str(self.Portfolio["AMD"].AveragePrice))

# %% [markdown]
# ![AMD.png](data:image/png;base64,...)

# %% [markdown]
# **Valor de paquete de 100 acciones al inicio:** $100,000
#
# **Valor de paquete de 100 acciones al final:** $106,300

# %% [markdown]
# # $3.Electronic Arts$

# %% [markdown]
# *Electronic Arts Inc. (EA) is an American video game company headquartered in Redwood City, California. It is the second-largest gaming company in the Americas and Europe by revenue and market capitalization after Activision Blizzard and ahead of Take-Two Interactive, CD Projekt, and Ubisoft as of May 2020.*

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2121, 1, 1)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        self.ea = self.AddEquity("EA", Resolution.Minute)
        self.ea.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        if not self.Portfolio.Invested:
            self.MarketOrder("EA", 100)
            self.Debug( str(self.Portfolio["EA"].AveragePrice))

# %% [markdown]
# ![EA.png](data:image/png;base64,...)

# %% [markdown]
# **Valor de paquete de 100 acciones al inicio:** $100,000
#
# **Valor de paquete de 100 acciones al final:** $106,500

# %% [markdown]
# # $4.PayPal$

# %% [markdown]
# *PayPal Holdings, Inc. is an American company operating an online payments system in the majority of countries that support online money transfers, and serves as an electronic alternative to traditional paper methods like checks and money orders. The company operates as a payment processor for online vendors, auction sites, and many other commercial users, for which it charges a fee.*

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2121, 1, 1)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        self.pypl = self.AddEquity("PYPL", Resolution.Minute)
        self.pypl.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        if not self.Portfolio.Invested:
            self.MarketOrder("PYPL", 100)
            self.Debug( str(self.Portfolio["PYPL"].AveragePrice))

# %% [markdown]
# ![PayPal.png](data:image/png;base64,...)

# %% [markdown]
# **Valor de paquete de 100 acciones al inicio:** $100,000
#
# **Valor de paquete de 100 acciones al final:** $118,000

# %% [markdown]
# # $5.MercadoLibre$

# %% [markdown]
# *Mercado Libre, Inc. (literally "free market" in Spanish, and known as Mercado Livre in Portuguese) is an Argentine company incorporated in the United States that operates online marketplaces dedicated to e-commerce and online auctions, including mercadolibre.com. As of 2016, Mercado Libre had 174.2 million users in Latin America, making it the region's most popular e-commerce site by number of visitors. The company has operations in Argentina, Bolivia, Brazil, Chile, Colombia, Costa Rica, Dominican Republic, Mexico, Spain, Ecuador, Guatemala, Honduras, Peru, Panama, Uruguay, and Venezuela.*

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2121, 1, 1)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        self.meli = self.AddEquity("MELI", Resolution.Minute)
        self.meli.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        if not self.Portfolio.Invested:
            self.MarketOrder("MELI", 100)
            self.Debug( str(self.Portfolio["MELI"].AveragePrice))

# %% [markdown]
# ![MercadoLibre.png](data:image/png;base64,...)

# %% [markdown]
# **Valor de paquete de 100 acciones al inicio:** $100,000
#
# **Valor de paquete de 100 acciones al final:** $230,000

# %% [markdown]
# # Portafolio

# %%
def Initialize(self):
        self.SetStartDate(2019, 5, 1)  # Set Start Date
        self.SetEndDate(2021, 5, 1) #Set End Date
        self.SetCash(1000000)  # Set Strategy Cash
        
        
        self.eth = self.AddEquity("ETH", Resolution.Minute)
        self.eth.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.amd = self.AddEquity("AMD", Resolution.Minute)
        self.amd.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.ea = self.AddEquity("EA", Resolution.Minute)
        self.ea.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.pypl = self.AddEquity("PYPL", Resolution.Minute)
        self.pypl.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.meli = self.AddEquity("MELI", Resolution.Minute)
        self.meli.SetDataNormalizationMode(DataNormalizationMode.Raw)

# %% [markdown]
# # Test 1

# %% [markdown]
# **Como monto inicial tomamos 1 millón de dólares y los dividimos de manera equitativa en las 5 compañías y tomamos un tiempo de inversión de 2 años**

# %%
def OnData(self, data):

        if not self.Portfolio.Invested:
            self.SetHoldings("ETH", 0.2)
            self.SetHoldings("AMD", 0.2)
            self.SetHoldings("EA", 0.2)
            self.SetHoldings("PYPL", 0.2)
            self.SetHoldings("MELI", 0.2)
            
            
            self.Log("Active Pos Ethereum " + str(self.Portfolio["ETH"].Quantity));
            self.Log("Active Pos AMD " + str(self.Portfolio["AMD"].Quantity));
            self.Log("Active Pos Electronic Arts " + str(self.Portfolio["EA"].Quantity));
            self.Log("Active Pos PayPal " + str(self.Portfolio["PYPL"].Quantity));
            self.Log("Active Pos MercadoLibre " + str(self.Portfolio["MELI"].Quantity));

# %% [markdown]
# ![Test 1.png](data:image/png;base64,...)

# %% [markdown]
# # Holdings (Nuestro acumulado con la inversión inicial): $2,226,515.33

# %% [markdown]
# # Unrealized (Ganancias netas) : $1,228,070.28

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Cantidad de acciones compradas:
#
# - Ethereum: 8949
#
# - AMD : 6916
#
# - Electronic Arts : 2096
#
# - PayPal : 1766
#
# - MercadoLibre : 410

# %% [markdown]
# # Valor de cada acción individual:
#
# - Ethereum: $22.35
#
# - AMD : $28.92
#
# - Electronic Arts : $95.42
#
# - PayPal : $113.25
#
# - MercadoLibre : $487.80

# %% [markdown]
# # Test 2

# %% [markdown]
# **Como monto inicial tomamos 1 millón de dólares y los dividimos de manera equitativa en las 5 compañías y tomamos un tiempo de inversión de 6 meses**

# %%
def Initialize(self):
        self.SetStartDate(2020, 11, 1)  # Set Start Date
        self.SetEndDate(2021, 5, 1) #Set End Date
        self.SetCash(1000000)  # Set Strategy Cash
        
        
        self.eth = self.AddEquity("ETH", Resolution.Minute)
        self.eth.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.amd = self.AddEquity("AMD", Resolution.Minute)
        self.amd.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.ea = self.AddEquity("EA", Resolution.Minute)
        self.ea.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.pypl = self.AddEquity("PYPL", Resolution.Minute)
        self.pypl.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.meli = self.AddEquity("MELI", Resolution.Minute)
        self.meli.SetDataNormalizationMode(DataNormalizationMode.Raw)

# %%
def OnData(self, data):

        if not self.Portfolio.Invested:
            self.SetHoldings("ETH", 0.2)
            self.SetHoldings("AMD", 0.2)
            self.SetHoldings("EA", 0.2)
            self.SetHoldings("PYPL", 0.2)
            self.SetHoldings("MELI", 0.2)
            
            
            self.Log("Active Pos Ethereum " + str(self.Portfolio["ETH"].Quantity));
            self.Log("Active Pos AMD " + str(self.Portfolio["AMD"].Quantity));
            self.Log("Active Pos Electronic Arts " + str(self.Portfolio["EA"].Quantity));
            self.Log("Active Pos PayPal " + str(self.Portfolio["PYPL"].Quantity));
            self.Log("Active Pos MercadoLibre " + str(self.Portfolio["MELI"].Quantity));

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Holdings (Nuestro acumulado con la inversión inicial): $1,335,580.24

# %% [markdown]
# # Unrealized (Ganancias netas) : $338,056.86

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Cantidad de acciones compradas:
#
# - Ethereum: 12329
#
# - AMD : 2642
#
# - Electronic Arts : 1656
#
# - PayPal : 1053
#
# - MercadoLibre : 162

# %% [markdown]
# # Valor de cada acción individual:
#
# - Ethereum: $16.22
#
# - AMD : $75.70
#
# - Electronic Arts : $120.77
#
# - PayPal : $113.25
#
# - MercadoLibre : $1234.57

# %% [markdown]
# # A pesar de que la inversión en los últimos 6 meses nos arroja un 27.52% de ganancias comparado a invertir en 2 años, al final tendremos menos acciones lo cual nos llevaría a menos ganancias en el futuro.

# %% [markdown]
# # Test 3

# %% [markdown]
# **Al observar la subida del valor de las acciones en los últimos 6 meses (a excepción de Ethereum), le daremos prioridad a invertir hace 2 años, lo cual nos permitirá tener más acciones al final.**
#
# **Ahora distribuiremos el porcentaje de inversión respecto a la rentabilidad de las acciones por su valor final en comparación a su valor inicial.**

# %%
def OnData(self, data):

        if not self.Portfolio.Invested:
            self.SetHoldings("ETH", 0.001)
            self.SetHoldings("AMD", 0.04)
            self.SetHoldings("EA", 0.04)
            self.SetHoldings("PYPL", 0.11)
            self.SetHoldings("MELI", 0.80)
            
            
            self.Log("Active Pos Ethereum " + str(self.Portfolio["ETH"].Quantity));
            self.Log("Active Pos AMD " + str(self.Portfolio["AMD"].Quantity));
            self.Log("Active Pos Electronic Arts " + str(self.Portfolio["EA"].Quantity));
            self.Log("Active Pos PayPal " + str(self.Portfolio["PYPL"].Quantity));
            self.Log("Active Pos MercadoLibre " + str(self.Portfolio["MELI"].Quantity));

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Holdings (Nuestro acumulado con la inversión inicial): $3,006,336.99

# %% [markdown]
# # Unrealized (Ganancias netas) : $2,013,935.52

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Cantidad de acciones compradas:
#
# - Ethereum: 44
#
# - AMD : 1383
#
# - Electronic Arts : 419
#
# - PayPal : 971
#
# - MercadoLibre : 1641

# %% [markdown]
# # Valor de cada acción individual:
#
# - Ethereum: $22.73
#
# - AMD : $28.92
#
# - Electronic Arts : $95.46
#
# - PayPal : $113.28
#
# - MercadoLibre : $487.51

# %% [markdown]
# # Estas son las ganacias maximizadas:

# %% [markdown]
# # ***$2,013,935.52***
