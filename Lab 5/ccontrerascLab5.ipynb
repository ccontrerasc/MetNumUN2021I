# %% [markdown]
# # $1.$ Netflix

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        #Dos años y 6 meses
        self.SetStartDate(2018, 10, 11)
        self.SetEndDate(2021, 4, 11)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        
        self.iwm = self.AddEquity("NFLX", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        #4. Debug the AveragePrice of IWM
        if not self.Portfolio.Invested:
            self.MarketOrder("NFLX", 100)
            self.Debug(str(self.Portfolio["NFLX"].AveragePrice))

# %% [markdown]
# ![Screenshot 2021-04-14 113605.png](data:image/png;base64,...)

# %% [markdown]
# # $2.$ Microsoft

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        #Dos años y 6 meses
        self.SetStartDate(2018, 10, 11)
        self.SetEndDate(2021, 4, 11)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        
        self.iwm = self.AddEquity("MSFT", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        #4. Debug the AveragePrice of IWM
        if not self.Portfolio.Invested:
            self.MarketOrder("MSFT", 100)
            self.Debug(str(self.Portfolio["MSFT"].AveragePrice))

# %% [markdown]
# ![Screenshot 2021-04-14 113740.png](data:image/png;base64,...)

# %% [markdown]
# # $3.$ Amazon

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        #Dos años y 6 meses
        self.SetStartDate(2018, 10, 11)
        self.SetEndDate(2021, 4, 11)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        
        self.iwm = self.AddEquity("AMZN", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        #4. Debug the AveragePrice of IWM
        if not self.Portfolio.Invested:
            self.MarketOrder("AMZN", 100)
            self.Debug(str(self.Portfolio["AMZN"].AveragePrice))

# %% [markdown]
# ![Screenshot 2021-04-14 113847.png](data:image/png;base64,...)

# %% [markdown]
# # $4.$ Google

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        #Dos años y 6 meses
        self.SetStartDate(2018, 10, 11)
        self.SetEndDate(2021, 4, 11)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        
        self.iwm = self.AddEquity("GOOG", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        #4. Debug the AveragePrice of IWM
        if not self.Portfolio.Invested:
            self.MarketOrder("GOOG", 100)
            self.Debug(str(self.Portfolio["GOOG"].AveragePrice))

# %% [markdown]
# ![Screenshot 2021-04-14 113958.png](data:image/png;base64,...)

# %% [markdown]
# # $5.$ AMD

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        #Dos años y 6 meses
        self.SetStartDate(2018, 10, 11)
        self.SetEndDate(2021, 4, 11)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        
        self.iwm = self.AddEquity("AMD", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        #4. Debug the AveragePrice of IWM
        if not self.Portfolio.Invested:
            self.MarketOrder("AMD", 100)
            self.Debug(str(self.Portfolio["AMD"].AveragePrice))

# %% [markdown]
# ![Screenshot 2021-04-14 114119.png](data:image/png;base64,...)
