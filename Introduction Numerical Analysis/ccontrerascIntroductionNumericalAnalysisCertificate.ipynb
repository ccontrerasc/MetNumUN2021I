# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Linkedin.png](data:image/png;base64,...)

# %% [markdown]
# # **Profile link on Linkedin:**
#
# https://www.linkedin.com/in/camilo-andres-contreras-cristancho-40b11a1b6/
